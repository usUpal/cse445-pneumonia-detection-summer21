# %% [markdown]
# # Download Dataset

# %%
from google.colab import files, output
files.upload()
# Out:
#      <input type="file" id="files-8c2412e8-6657-4dab-bd75-99632eaf0a42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c2412e8-6657-4dab-bd75-99632eaf0a42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"usupal","key":"8cf51244cd302946f9df4365761cf3a7"}'}

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle/
# !cp kaggle.json ~/.kaggle/

# change permission of the file
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !mkdir Coronahack-Chest-XRay-Dataset
# %cd Coronahack-Chest-XRay-Dataset

# %%
# !kaggle datasets download praveengovi/coronahack-chest-xraydataset
# Out:
# Downloading coronahack-chest-xraydataset.zip to /content
#  99% 1.18G/1.19G [00:10<00:00, 124MB/s]
# 100% 1.19G/1.19G [00:10<00:00, 124MB/s]

# %%
# %pwd
# Out:
# '/content'

# %%
! unzip coronahack-chest-xraydataset.zip
output.clear()

# %%
# remove zipped dataset
# !rm coronahack-chest-xraydataset.zip

# %% [markdown]
# # Import Libraries

# %%
# Common lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Utils
from tqdm import tqdm
import datetime

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, confusion_matrix, auc

# Tensorflow
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, Flatten, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, TruePositives, TrueNegatives, FalsePositives, FalseNegatives
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from tensorflow.keras.layers.experimental.preprocessing import Resizing, Rescaling
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

print("import done")
# Out:
# import done

# %% [markdown]
# # EDA

# %%
# Init variables
input_folder = '/content/Coronahack-Chest-XRay-Dataset'
test_img_folder = os.path.join(input_folder,'Coronahack-Chest-XRay-Dataset', 'test')
train_img_folder = os.path.join(input_folder, 'Coronahack-Chest-XRay-Dataset', 'train')
metadata_df = pd.read_csv(('/content/Chest_xray_Corona_Metadata.csv'), index_col=0)

# %%
metadata_df.describe()
# Out:
#          X_ray_image_name  ... Label_1_Virus_category
# count                5910  ...                   4334
# unique               5910  ...                      3
# top     IM-0577-0001.jpeg  ...               bacteria
# freq                    1  ...                   2777
#
# [4 rows x 5 columns]

# %%
# Split to train & test set
train_df = metadata_df[metadata_df.Dataset_type == 'TRAIN'].reset_index(drop=True)
test_df = metadata_df[metadata_df.Dataset_type == 'TEST'].reset_index(drop=True)

# Check train_df size + test_df size == metadata_df size
assert train_df.size + test_df.size == metadata_df.size

print(f'Shape of train data: { train_df.shape }')
print(f'Shape of test data: { test_df.shape }')

train_df.sample(10)
# Out:
# Shape of train data: (5286, 5)
# Shape of test data: (624, 5)
#                     X_ray_image_name  ... Label_1_Virus_category
# 4647    person630_bacteria_2512.jpeg  ...               bacteria
# 3635    person328_bacteria_1511.jpeg  ...               bacteria
# 537                IM-0675-0001.jpeg  ...                    NaN
# 3070   person1912_bacteria_4816.jpeg  ...               bacteria
# 4022    person491_bacteria_2075.jpeg  ...               bacteria
# 543                IM-0669-0001.jpeg  ...                    NaN
# 4350    person549_bacteria_2307.jpeg  ...               bacteria
# 1090  NORMAL2-IM-1094-0001-0002.jpeg  ...                    NaN
# 3932    person512_bacteria_2154.jpeg  ...               bacteria
# 3580        person339_virus_695.jpeg  ...                  Virus
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Identify null values from datasets

# %%
def count_plot_null_value(dataset, xticks):
    fig = plt.figure()
    if dataset == 'train':
        dataset_df = train_df
    else:
        dataset_df = test_df
    ax = sns.barplot(x=dataset_df.isnull().sum(), 
                     y=dataset_df.columns,
                     order=['X_ray_image_name', 'Dataset_type', 'Label', 'Label_1_Virus_category', 'Label_2_Virus_category'],
                     palette="Accent")
    ax.set_xticks(xticks)
    ax.set_ylabel('Column')
    ax.set_xlabel('Count')
    ax.set_title(f'Number of null values of each column in { dataset } data')

    # Add text to chart
    for p in ax.patches:
        ax.annotate(int(p.get_width()),
                    (p.get_width() + 10, p.get_y() + p.get_height() / 2),
                    va='center',
                    size=12)
    plt.show()
        
count_plot_null_value('train', np.arange(0, 7000, 1000))
count_plot_null_value('test', np.arange(0, 750, 100))

# %%
# fill na
train_df.fillna('unknown', inplace=True)
test_df.fillna('unknown', inplace=True)

# %% [markdown]
# count value in Label Column

# %%
def count_plot_value_in_column(column, dataset, ax, order=None):
    ax = sns.countplot(y=column, 
                       data=dataset, 
                       palette='Accent',
                       ax=ax,
                       order=order)
    return ax

def add_annotate_to_chart(ax):
    for p in ax.patches:
        ax.annotate(int(p.get_width()),
                    (p.get_width() + 10, p.get_y() + p.get_height() / 2),
                    va='center',
                    size=12)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Train set
ax = count_plot_value_in_column('Label', train_df, axs[0])
ax.set_xticks(np.arange(0, 5000, 500))
ax.set_title('Train set')
add_annotate_to_chart(ax)

# Test set
ax = count_plot_value_in_column('Label', test_df, axs[1])
ax.set_xticks(np.arange(0, 500, 50))
ax.set_title('Test set')
add_annotate_to_chart(ax)

fig.suptitle('Number of each values in Label column', size=15)
plt.show()

# %% [markdown]
# Make sure that all normal cases go with unknow value in Label_1_Virus_category and Label_2_Virus_category

# %%
train_normal = train_df[train_df.Label == 'Normal']
test_normal = test_df[test_df.Label == 'Normal']

train_normal_with_unknow = train_normal[(train_normal.Label_1_Virus_category == 'unknow') & (train_normal.Label_2_Virus_category == 'unknow')]
test_normal_with_unknow = test_normal[(test_normal.Label_1_Virus_category == 'unknow') & (test_normal.Label_2_Virus_category == 'unknow')]

total_normal_cases = train_normal.shape[0] + test_normal.shape[0]
total_normal_with_unknow_cases = train_normal_with_unknow.shape[0] + test_normal_with_unknow.shape[0]

print(f'Label = Normal: { total_normal_cases }')
print(f"Label = Normal & Label_1 = unknow & Label_2 = unknow: { total_normal_with_unknow_cases }")

assert total_normal_cases + total_normal_with_unknow_cases
# Out:
# Label = Normal: 1576
# Label = Normal & Label_1 = unknow & Label_2 = unknow: 1576

# %% [markdown]
# Count value in Label_1_Virus_category column

# %%
train_pnemonia = train_df[~train_df.index.isin(train_normal.index)]
test_pnemonia = test_df[~test_df.index.isin(test_normal.index)]

assert train_pnemonia.shape[0] + train_normal.shape[0] == train_df.shape[0]
assert test_pnemonia.shape[0] + test_normal.shape[0] == test_df.shape[0]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Train pnemonia
ax = count_plot_value_in_column('Label_1_Virus_category', 
                                train_pnemonia, 
                                axs[0])
ax.set_xticks(np.arange(0, 3500, 500))
ax.set_title('Pnemonia cases in train set')
add_annotate_to_chart(ax)

# Test pnemonia
ax = count_plot_value_in_column('Label_1_Virus_category',
                                test_pnemonia,
                                axs[1])
ax.set_xticks(np.arange(0, 350, 50))
ax.set_title('Pnemonia cases in test set')
add_annotate_to_chart(ax)

fig.suptitle('Number of each values in Label_1_Virus_category', size=15)

plt.show()

# %% [markdown]
# Count value in Label_2_Virus_category column

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Train pnemonia
ax = count_plot_value_in_column('Label_2_Virus_category', 
                                train_pnemonia, 
                                axs[0])
ax.set_xticks(np.arange(0, 5000, 500))
ax.set_title('Pnemonia cases in train set')
add_annotate_to_chart(ax)

# Test pnemonia 
ax = count_plot_value_in_column('Label_2_Virus_category', test_pnemonia, axs[1])
ax.set_xticks(np.arange(0, 500, 50))
ax.set_title('Pnemonia cases in test set')
add_annotate_to_chart(ax)

fig.suptitle('Number of each values in Label_2_Virus_category', size=15)

plt.show()

# %% [markdown]
# Inference from charts
#
#
# 1.   We have 2 cases that is Pnemonia and Normal case.
# 2.   Pnemonia cases is much more than Normal cases in both train set and test set.
# 3.   All Normal cases is labeled as unknow/null in Label_1_Virus_category and Label_2_Virus_category.
# 4.   All Pnemonia cases is labeled as bacteria, virus, stress-smoking and dont have any unknow/null value in Label_1_Virus_category in both train set and test set.
# 5.   In train set, most of pnemonia case is labeled as unknow/null value (3875/3944).
# 6. In test set, all pnemonia case is labels as unknow/null value.
# 7. In Label_1_Virus_category, those value are different to much.
# 8.   In Label_2_Virus_category, if we remove all unknow value then we just have 69 sample.
# 9. Thus we are going to construct a model which classifies Normal and Pnemonia cases.
# 10. Cause the difference of Pnemonia and Normal cases so that we should use AUC or F1 score to evaluate the goodness of model.

# %% [markdown]
# ## Visualization

# %%
# plot random 6 images in train dataset
assert os.path.exists(train_img_folder)
assert os.path.exists(test_img_folder)

random_train_img = train_df.sample(6).reset_index(drop=True)

fig = plt.figure(figsize=(15, 15))
for i in range(6):
    ax = plt.subplot(3, 2, i+1)
    img_path = os.path.join(train_img_folder, random_train_img.loc[i, 'X_ray_image_name'])
    label = random_train_img.loc[i, 'Label']
    img = load_img(img_path)
    ax.axis('off')
    ax.set_title(label, size=15)
    ax.imshow(img)
    
plt.show()

# %% [markdown]
# ## Image histogram
# An image histogram is a type of histogram that acts as a graphical representation of the tonal distribution in a digital image. It plots the number of pixels for each tonal value. By looking at the histogram for a specific image a viewer will be able to judge the entire tonal distribution at a glance.

# %% [markdown]
# Image Histogram of 5 normal cases

# %%
normal_case_img_name = train_df[train_df.Label == 'Normal'].X_ray_image_name[:5]

fig, axs = plt.subplots(5, 2, figsize=(15, 20))
for idx, img_name in enumerate(normal_case_img_name):
    # Plot image
    img_path = os.path.join(train_img_folder, img_name)
    img = load_img(img_path)
    img = img.resize((700, 700))
    axs[idx, 0].imshow(img)
    axs[idx, 0].axis('off')
    # Plot image histogram
    img_arr = img_to_array(img)
    axs[idx, 1].hist(img_arr.ravel(), 256)
    
axs[0, 0].set_title('Image')    
axs[0, 1].set_title('Image histogram')
fig.suptitle('Normal Case', size = 20)
plt.show()

# %% [markdown]
# Image Histogram of 5 pneumonia cases

# %%
pnemonia_case_img_name = train_df[train_df.Label == 'Pnemonia'].X_ray_image_name[:5]

fig, axs = plt.subplots(5, 2, figsize=(15, 20))
for idx, img_name in enumerate(pnemonia_case_img_name):
    # Plot image
    img_path = os.path.join(train_img_folder, img_name)
    img = load_img(img_path)
    img = img.resize((700, 700))
    axs[idx, 0].imshow(img)
    axs[idx, 0].axis('off')
    # Plot image histogram
    img_arr = img_to_array(img)
    axs[idx, 1].hist(img_arr.ravel(), 256)

axs[0, 0].set_title('Image')
axs[0, 1].set_title('Image histogram')
fig.suptitle('Pnemonia Cases', size=20)
plt.show()

# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## Augmentation

# %%
def load_img_path(quantity, dataset):
    if dataset == 'train':
        df = train_df
        folder = train_img_folder
    elif dataset == 'test':
        df = test_df
        folder = test_img_folder
    if quantity <= 0:
        return None
    img_names = df.X_ray_image_name[:quantity]
    img_paths = [os.path.join(folder, img_name) for img_name in img_names]
    return img_paths

def img_path_to_array(img_paths):
    img_arr = [img_to_array(load_img(img_path).resize((500, 500))) for img_path in tqdm(img_paths)]
    img_arr = np.array(img_arr)
    return img_arr

def show_img(img):
    plt.imshow(array_to_img(img))
    
def show_multi_img(img_arr):
    fig = plt.figure(figsize=(20,10))
    for i in range(len(img_arr)):
        plt.subplot(len(img_arr) / 4, 4, i+1)
        show_img(img_arr[i])
        plt.axis('off')

# %%
train_datagen = ImageDataGenerator(rotation_range=10,
                              brightness_range=(0.1, 1.2),
                              horizontal_flip=True,
                              zoom_range=[0.75, 1])
test_datagen = ImageDataGenerator()

# %% [markdown]
# Plot images after Augmentation

# %%
img_paths = load_img_path(100, 'train')
img_arr = img_path_to_array(img_paths)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 20.32it/s]

# %%
aug_imgs = train_datagen.flow(img_arr ,batch_size=8)
print(f'Number of batches: { len(aug_imgs) }')
# Out:
# Number of batches: 13

# %%
# augmented Images
show_multi_img(aug_imgs[0])

# %% [markdown]
# ## Train-Test split

# %%
train_datagen = ImageDataGenerator(rotation_range=10,
                              brightness_range=(0.8, 1.2),
                              zoom_range=[0.75, 1],
                              horizontal_flip=True)
test_datagen = ImageDataGenerator()

# %%
train_df, valid_df = train_test_split(train_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_batches = train_datagen.flow_from_dataframe(train_df,
                                             directory=train_img_folder,
                                             x_col='X_ray_image_name',
                                             y_col='Label',
                                             class_mode='binary',
                                             batch_size=128)

valid_batches = test_datagen.flow_from_dataframe(valid_df,
                                             directory=train_img_folder,
                                             x_col='X_ray_image_name',
                                             y_col='Label',
                                             class_mode='binary',
                                             batch_size=128)

test_batches = test_datagen.flow_from_dataframe(test_df,
                                            directory=test_img_folder,
                                            x_col='X_ray_image_name',
                                            y_col='Label',
                                            class_mode='binary',
                                            batch_size=8,
                                            shuffle=False)
# Out:
# Found 4228 validated image filenames belonging to 2 classes.
# Found 1058 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.

# %%
print(f'Label encode: { valid_batches.class_indices }')
# Out:
# Label encode: {'Normal': 0, 'Pnemonia': 1}

# %%
train_batches_series = pd.Series(train_batches.classes)
valid_batches_series = pd.Series(valid_batches.classes)

print(f'Value count in train_batches: \n{ train_batches_series.value_counts() }')
print(f'Value count in valid_batches: \n{ valid_batches_series.value_counts() }')
# Out:
# Value count in train_batches:
# 1    3169
# 0    1059
# dtype: int64
# Value count in valid_batches:
# 1    775
# 0    283
# dtype: int64

# %% [markdown]
# ## Fine Tuning

# %%
def create_dir(dir_path):
    if not os.path.exists(dir_path):
        os.mkdir(dir_path)
        
create_dir('models')

# %% [markdown]
# ## Preprocessing Layer

# %%
resize_and_rescale = Sequential([
    Resizing(224, 224),
    Rescaling(1./255)
])

# %% [markdown]
# # Fitting Model

# %%
metrics = [TruePositives(name='TP'),
           TrueNegatives(name='TN'),
           FalsePositives(name='FP'),
           FalseNegatives(name='FN'),
           AUC(curve='PR', name='AUC')]

# %%
#!pip install git+https://github.com/qubvel/classification_models.git

# %%
#using ResNet101
INPUT_SHAPE = (224,224,3) 

#get the pretrained model
base_model = tf.keras.applications.VGG16(input_shape= INPUT_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False
base_model.summary()
# from classification_models.keras import Classifiers

# ResNet18, preprocess_input = Classifiers.get('resnet18')
# base_model = ResNet18((224, 224, 3), include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Preprocess layer
ft_vgg16 = Sequential([resize_and_rescale]) 
# Feature extractor
ft_vgg16.add(base_model)
# Classifier
ft_vgg16.add(GlobalAveragePooling2D())
ft_vgg16.add(Dense(1, activation='sigmoid'))

# %%
# Freeze
#for layer in ft_resnet34.layers[1].layers[:50]:
#    layer.trainable = False

# %%
vgg16_dir = 'models/vgg16'
vgg16_file = 'best_vgg16.hdf5'

create_dir(vgg16_dir)

checkpoint = ModelCheckpoint(os.path.join(vgg16_dir, vgg16_file),
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             save_weights_only=False)

early_stopping = EarlyStopping(monitor='val_loss',
                               patience=30,
                               verbose=1,
                               restore_best_weights=True)

# %%
# # Initialize TensorBoard
# log_dir = 'models/resnet18/logs'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
epochs = 50
learning_rate = 1e-4

ft_vgg16.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=metrics)

training_time_start = datetime.datetime.now()

vgg16_history = ft_vgg16.fit(train_batches,
                                epochs=epochs,
                                verbose=2,
                                callbacks=[checkpoint, early_stopping],
                                validation_data=valid_batches,
                                steps_per_epoch=len(train_batches),
                                validation_steps=len(valid_batches))

training_time_end = datetime.datetime.now()
# Out:
# Epoch 1/50
# 34/34 - 183s - loss: 0.5779 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.7721 - val_loss: 0.5824 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.7681
#
# Epoch 00001: val_loss improved from inf to 0.58239, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 2/50
# 34/34 - 137s - loss: 0.5653 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.8075 - val_loss: 0.5764 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.8093
#
# Epoch 00002: val_loss improved from 0.58239 to 0.57644, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 3/50
# 34/34 - 136s - loss: 0.5590 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.8525 - val_loss: 0.5719 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.8512
#
# Epoch 00003: val_loss improved from 0.57644 to 0.57189, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 4/50
# 34/34 - 136s - loss: 0.5537 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.8898 - val_loss: 0.5684 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.8842
#
# Epoch 00004: val_loss improved from 0.57189 to 0.56836, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 5/50
# 34/34 - 135s - loss: 0.5500 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9127 - val_loss: 0.5648 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9074
#
# Epoch 00005: val_loss improved from 0.56836 to 0.56481, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 6/50
# 34/34 - 135s - loss: 0.5458 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9336 - val_loss: 0.5608 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9264
#
# Epoch 00006: val_loss improved from 0.56481 to 0.56077, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 7/50
# 34/34 - 136s - loss: 0.5421 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9440 - val_loss: 0.5566 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9405
#
# Epoch 00007: val_loss improved from 0.56077 to 0.55663, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 8/50
# 34/34 - 133s - loss: 0.5385 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9525 - val_loss: 0.5520 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9521
#
# Epoch 00008: val_loss improved from 0.55663 to 0.55203, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 9/50
# 34/34 - 135s - loss: 0.5353 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9557 - val_loss: 0.5488 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9586
#
# Epoch 00009: val_loss improved from 0.55203 to 0.54878, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 10/50
# 34/34 - 137s - loss: 0.5320 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9595 - val_loss: 0.5446 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9630
#
# Epoch 00010: val_loss improved from 0.54878 to 0.54464, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 11/50
# 34/34 - 135s - loss: 0.5295 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9616 - val_loss: 0.5403 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9668
#
# Epoch 00011: val_loss improved from 0.54464 to 0.54030, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 12/50
# 34/34 - 136s - loss: 0.5252 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9650 - val_loss: 0.5371 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9700
#
# Epoch 00012: val_loss improved from 0.54030 to 0.53705, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 13/50
# 34/34 - 133s - loss: 0.5226 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9630 - val_loss: 0.5341 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9725
#
# Epoch 00013: val_loss improved from 0.53705 to 0.53415, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 14/50
# 34/34 - 133s - loss: 0.5194 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9668 - val_loss: 0.5302 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9734
#
# Epoch 00014: val_loss improved from 0.53415 to 0.53017, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 15/50
# 34/34 - 135s - loss: 0.5162 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9672 - val_loss: 0.5265 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9756
#
# Epoch 00015: val_loss improved from 0.53017 to 0.52650, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 16/50
# 34/34 - 135s - loss: 0.5120 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9701 - val_loss: 0.5219 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9766
#
# Epoch 00016: val_loss improved from 0.52650 to 0.52192, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 17/50
# 34/34 - 134s - loss: 0.5088 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9697 - val_loss: 0.5180 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9773
#
# Epoch 00017: val_loss improved from 0.52192 to 0.51805, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 18/50
# 34/34 - 134s - loss: 0.5048 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9712 - val_loss: 0.5146 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9779
#
# Epoch 00018: val_loss improved from 0.51805 to 0.51460, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 19/50
# 34/34 - 137s - loss: 0.5031 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9699 - val_loss: 0.5115 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9791
#
# Epoch 00019: val_loss improved from 0.51460 to 0.51145, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 20/50
# 34/34 - 135s - loss: 0.5004 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9708 - val_loss: 0.5078 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9796
#
# Epoch 00020: val_loss improved from 0.51145 to 0.50777, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 21/50
# 34/34 - 135s - loss: 0.4965 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9719 - val_loss: 0.5048 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9802
#
# Epoch 00021: val_loss improved from 0.50777 to 0.50476, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 22/50
# 34/34 - 135s - loss: 0.4941 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9718 - val_loss: 0.5015 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9804
#
# Epoch 00022: val_loss improved from 0.50476 to 0.50147, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 23/50
# 34/34 - 135s - loss: 0.4914 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9720 - val_loss: 0.4979 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9812
#
# Epoch 00023: val_loss improved from 0.50147 to 0.49789, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 24/50
# 34/34 - 133s - loss: 0.4880 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9724 - val_loss: 0.4942 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9810
#
# Epoch 00024: val_loss improved from 0.49789 to 0.49421, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 25/50
# 34/34 - 137s - loss: 0.4858 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9724 - val_loss: 0.4913 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9815
#
# Epoch 00025: val_loss improved from 0.49421 to 0.49128, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 26/50
# 34/34 - 137s - loss: 0.4820 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9742 - val_loss: 0.4887 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9819
#
# Epoch 00026: val_loss improved from 0.49128 to 0.48867, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 27/50
# 34/34 - 134s - loss: 0.4792 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9726 - val_loss: 0.4844 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9818
#
# Epoch 00027: val_loss improved from 0.48867 to 0.48436, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 28/50
# 34/34 - 135s - loss: 0.4766 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9739 - val_loss: 0.4817 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9822
#
# Epoch 00028: val_loss improved from 0.48436 to 0.48168, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 29/50
# 34/34 - 136s - loss: 0.4743 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9716 - val_loss: 0.4782 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9823
#
# Epoch 00029: val_loss improved from 0.48168 to 0.47825, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 30/50
# 34/34 - 135s - loss: 0.4729 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9726 - val_loss: 0.4748 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9825
#
# Epoch 00030: val_loss improved from 0.47825 to 0.47483, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 31/50
# 34/34 - 134s - loss: 0.4695 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9735 - val_loss: 0.4724 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9827
#
# Epoch 00031: val_loss improved from 0.47483 to 0.47236, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 32/50
# 34/34 - 132s - loss: 0.4668 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9743 - val_loss: 0.4706 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9829
#
# Epoch 00032: val_loss improved from 0.47236 to 0.47057, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 33/50
# 34/34 - 134s - loss: 0.4634 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9746 - val_loss: 0.4683 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9831
#
# Epoch 00033: val_loss improved from 0.47057 to 0.46831, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 34/50
# 34/34 - 132s - loss: 0.4620 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9745 - val_loss: 0.4659 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9830
#
# Epoch 00034: val_loss improved from 0.46831 to 0.46593, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 35/50
# 34/34 - 132s - loss: 0.4614 - TP: 3169.0000 - TN: 1.0000 - FP: 1058.0000 - FN: 0.0000e+00 - AUC: 0.9738 - val_loss: 0.4632 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9832
#
# Epoch 00035: val_loss improved from 0.46593 to 0.46324, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 36/50
# 34/34 - 132s - loss: 0.4579 - TP: 3169.0000 - TN: 0.0000e+00 - FP: 1059.0000 - FN: 0.0000e+00 - AUC: 0.9735 - val_loss: 0.4605 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9833
#
# Epoch 00036: val_loss improved from 0.46324 to 0.46054, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 37/50
# 34/34 - 133s - loss: 0.4550 - TP: 3169.0000 - TN: 6.0000 - FP: 1053.0000 - FN: 0.0000e+00 - AUC: 0.9737 - val_loss: 0.4583 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9835
#
# Epoch 00037: val_loss improved from 0.46054 to 0.45825, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 38/50
# 34/34 - 133s - loss: 0.4548 - TP: 3168.0000 - TN: 5.0000 - FP: 1054.0000 - FN: 1.0000 - AUC: 0.9749 - val_loss: 0.4548 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9836
#
# Epoch 00038: val_loss improved from 0.45825 to 0.45480, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 39/50
# 34/34 - 134s - loss: 0.4500 - TP: 3169.0000 - TN: 5.0000 - FP: 1054.0000 - FN: 0.0000e+00 - AUC: 0.9746 - val_loss: 0.4519 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9837
#
# Epoch 00039: val_loss improved from 0.45480 to 0.45193, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 40/50
# 34/34 - 135s - loss: 0.4491 - TP: 3168.0000 - TN: 7.0000 - FP: 1052.0000 - FN: 1.0000 - AUC: 0.9752 - val_loss: 0.4502 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9837
#
# Epoch 00040: val_loss improved from 0.45193 to 0.45015, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 41/50
# 34/34 - 134s - loss: 0.4461 - TP: 3169.0000 - TN: 10.0000 - FP: 1049.0000 - FN: 0.0000e+00 - AUC: 0.9752 - val_loss: 0.4477 - val_TP: 775.0000 - val_TN: 0.0000e+00 - val_FP: 283.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9839
#
# Epoch 00041: val_loss improved from 0.45015 to 0.44772, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 42/50
# 34/34 - 134s - loss: 0.4462 - TP: 3167.0000 - TN: 17.0000 - FP: 1042.0000 - FN: 2.0000 - AUC: 0.9750 - val_loss: 0.4444 - val_TP: 775.0000 - val_TN: 2.0000 - val_FP: 281.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9841
#
# Epoch 00042: val_loss improved from 0.44772 to 0.44442, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 43/50
# 34/34 - 135s - loss: 0.4410 - TP: 3168.0000 - TN: 16.0000 - FP: 1043.0000 - FN: 1.0000 - AUC: 0.9762 - val_loss: 0.4420 - val_TP: 775.0000 - val_TN: 2.0000 - val_FP: 281.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9839
#
# Epoch 00043: val_loss improved from 0.44442 to 0.44200, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 44/50
# 34/34 - 134s - loss: 0.4418 - TP: 3165.0000 - TN: 23.0000 - FP: 1036.0000 - FN: 4.0000 - AUC: 0.9744 - val_loss: 0.4391 - val_TP: 775.0000 - val_TN: 4.0000 - val_FP: 279.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9841
#
# Epoch 00044: val_loss improved from 0.44200 to 0.43906, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 45/50
# 34/34 - 140s - loss: 0.4391 - TP: 3167.0000 - TN: 36.0000 - FP: 1023.0000 - FN: 2.0000 - AUC: 0.9739 - val_loss: 0.4367 - val_TP: 775.0000 - val_TN: 5.0000 - val_FP: 278.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9841
#
# Epoch 00045: val_loss improved from 0.43906 to 0.43667, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 46/50
# 34/34 - 137s - loss: 0.4376 - TP: 3168.0000 - TN: 42.0000 - FP: 1017.0000 - FN: 1.0000 - AUC: 0.9740 - val_loss: 0.4340 - val_TP: 775.0000 - val_TN: 10.0000 - val_FP: 273.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9842
#
# Epoch 00046: val_loss improved from 0.43667 to 0.43403, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 47/50
# 34/34 - 136s - loss: 0.4378 - TP: 3163.0000 - TN: 46.0000 - FP: 1013.0000 - FN: 6.0000 - AUC: 0.9721 - val_loss: 0.4318 - val_TP: 775.0000 - val_TN: 10.0000 - val_FP: 273.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9843
#
# Epoch 00047: val_loss improved from 0.43403 to 0.43184, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 48/50
# 34/34 - 137s - loss: 0.4338 - TP: 3164.0000 - TN: 53.0000 - FP: 1006.0000 - FN: 5.0000 - AUC: 0.9743 - val_loss: 0.4292 - val_TP: 775.0000 - val_TN: 13.0000 - val_FP: 270.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9844
#
# Epoch 00048: val_loss improved from 0.43184 to 0.42919, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 49/50
# 34/34 - 137s - loss: 0.4304 - TP: 3164.0000 - TN: 63.0000 - FP: 996.0000 - FN: 5.0000 - AUC: 0.9757 - val_loss: 0.4275 - val_TP: 775.0000 - val_TN: 13.0000 - val_FP: 270.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9845
#
# Epoch 00049: val_loss improved from 0.42919 to 0.42752, saving model to models/vgg16/best_vgg16.hdf5
# Epoch 50/50
# 34/34 - 137s - loss: 0.4297 - TP: 3164.0000 - TN: 65.0000 - FP: 994.0000 - FN: 5.0000 - AUC: 0.9748 - val_loss: 0.4262 - val_TP: 775.0000 - val_TN: 12.0000 - val_FP: 271.0000 - val_FN: 0.0000e+00 - val_AUC: 0.9846
#
# Epoch 00050: val_loss improved from 0.42752 to 0.42621, saving model to models/vgg16/best_vgg16.hdf5

# %%
from google.colab import files
files.download('/content/models/vgg16/best_vgg16.hdf5')

# %%
total_training_seconds = (training_time_end - training_time_start).seconds
print('Total training time: ', str(datetime.timedelta(seconds=total_training_seconds)))
# Out:
# Total training time:  1:54:20

# %% [markdown]
# # Evaluate

# %%
vgg16_hist_df = pd.DataFrame(vgg16_history.history)

# %% [markdown]
# Plot over entire epochs

# %%
vgg16_hist_df.loc[:, ['loss', 'val_loss']].plot()
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
vgg16_hist_df.loc[:, ['AUC', 'val_AUC']].plot()
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# Plot over half first and first last epochs

# %%
num_of_epochs = vgg16_hist_df.shape[0]
half_epoch = int(num_of_epochs / 2)

first_half_vgg16_hist = vgg16_hist_df.loc[:half_epoch]
first_title = f'Loss value at epoch 0 - { half_epoch }'

last_half_vgg16_hist = vgg16_hist_df.loc[half_epoch:len(vgg16_hist_df)]
last_title = f'Loss value at epoch { half_epoch } - { len(vgg16_hist_df) }'

hists = [first_half_vgg16_hist, last_half_vgg16_hist]
titles = [first_title, last_title]

for i in range(2):
    ax = hists[i][['loss', 'val_loss']].plot()
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss value')
    ax.set_title(titles[i])
plt.show()

# %%
first_title = f'AUC value at epoch 0 - { half_epoch }'
last_title = f'AUC value at epoch { half_epoch } - { len(vgg16_hist_df) }'

titles = [first_title, last_title]

for i in range(2):
    ax = hists[i][['AUC', 'val_AUC']].plot()
    ax.set_xlabel('Epoch')
    ax.set_ylabel('AUC value')
    ax.set_title(titles[i])
plt.show()

# %%
evaluate_vgg16 = ft_vgg16.evaluate(test_batches, verbose=1)
# Out:
# 78/78 [==============================] - 14s 142ms/step - loss: 0.5939 - TP: 390.0000 - TN: 1.0000 - FP: 233.0000 - FN: 0.0000e+00 - AUC: 0.9199

# %%
loss, tp, tn, fp, fn, auc = evaluate_vgg16[0], evaluate_vgg16[1], evaluate_vgg16[2], evaluate_vgg16[3], evaluate_vgg16[4], evaluate_vgg16[5]
print(f'Test loss: { loss }')
print(f'True positive: { tp }')
print(f'True negative: { tn }')
print(f'False positive: { fp }')
print(f'False negative: { fn }')
print('AUC: %.2f' % auc)
# Out:
# Test loss: 0.593926727771759
# True positive: 390.0
# True negative: 1.0
# False positive: 233.0
# False negative: 0.0
# AUC: 0.92

# %% [markdown]
# Plot PR curve and find optimal threshold

# %%
def find_optimal_threshold(precision, recall, threshold):
    f1_score = (2 * precision * recall) / (precision + recall)
    best_idx = np.argmax(f1_score)
    best_threshold = threshold[best_idx]
    return best_threshold, best_idx

# %% [markdown]
# Find the best threshold

# %%
y_true = test_batches.classes
y_predict = ft_vgg16.predict(test_batches)
precision, recall, threshold = precision_recall_curve(y_true, y_predict)
best_threshold, best_idx = find_optimal_threshold(precision, recall, threshold)
print('Best threshold: {}'.format(best_threshold))
# Out:
# Best threshold: 0.7461386322975159

# %% [markdown]
# Plot ROC curve

# %%
import numpy as np
from sklearn import metrics
plt.figure(figsize=(7, 5))
auc_score = metrics.auc(recall, precision)
plt.plot([1, 0], [0, 1], linestyle='--', color='black', label='No skill')
plt.plot(recall, precision, linewidth=3, label='vgg16')
plt.plot(recall[best_idx], precision[best_idx], 
         marker='o', color='black', 
         label='Best_theshold', linestyle='', markersize='7')
plt.xlabel('Recall', size=13)
plt.ylabel('Precision', size=13)
plt.title('Precision-Recall curve (AUC - {:.4f})'.format(auc_score), size=15)
plt.legend()
plt.show()

# %% [markdown]
# Predict and plot confusion matrix

# %%
y_predict = (y_predict >= best_threshold).astype('int')
y_predict = np.reshape(y_predict, -1)
cfs_matrix = confusion_matrix(y_true, y_predict)

# %%
label = ['Normal', 'Pneumonia']

plt.figure(figsize=(6, 5))
plt.imshow(cfs_matrix, cmap=plt.cm.Accent)
plt.colorbar()
for i in range(len(label)):
    for j in range(len(label)):
        plt.text(j, i, cfs_matrix[i, j],
                 horizontalalignment='center', verticalalignment='center', size=14)
plt.xticks(np.arange(len(label)), label)
plt.yticks(np.arange(len(label)), label)
plt.xlabel('Predicted label', size=13)
plt.ylabel('True label', size=13)
plt.title('Confusion matrix[vgg16]', size=15)
plt.show()
